# %%
import pandas as pd
df = pd.read_csv("result.csv")
df1 = df.groupby("Movie_or_TV_name").size().reset_index(name="Number of shared actors")
sorted = df1.sort_values(by="Number of shared actors" , ascending=False) 
sorted.index = list(range(0,int(df1.count()[0])))
sorted[0:50]
# Out:
#                                 Movie_or_TV_name  Number of shared actors
# 0                     Star Trek: Deep Space Nine                      540
# 1                                             ER                      116
# 2                             Star Trek: Voyager                      113
# 3                                      NYPD Blue                      111
# 4                 Star Trek: The Next Generation                      109
# 5                                       L.A. Law                      104
# 6                                            JAG                       99
# 7                              Murder, She Wrote                       86
# 8                                         Hunter                       82
# 9                 CSI: Crime Scene Investigation                       77
# 10                                  The Practice                       77
# 11                                       Matlock                       76
# 12                         Star Trek: Enterprise                       71
# 13                                          NCIS                       70
# 14                              Diagnosis Murder                       70
# 15                                   The X-Files                       69
# 16                                     Cold Case                       69
# 17                               Without a Trace                       69
# 18                             Days of Our Lives                       68
# 19                                Criminal Minds                       61
# 20                                 The West Wing                       61
# 21                          Beverly Hills, 90210                       59
# 22                             Hill Street Blues                       58
# 23                    The Young and the Restless                       56
# 24                                       Charmed                       54
# 25                                   Judging Amy                       54
# 26                                 Melrose Place                       53
# 27                                   Law & Order                       52
# 28                                  Murphy Brown                       51
# 29                                  Chicago Hope                       50
# 30                          Walker, Texas Ranger                       49
# 31                                 The Pretender                       49
# 32                              General Hospital                       47
# 33                                      Profiler                       46
# 34                                      Seinfeld                       46
# 35                           Jake and the Fatman                       46
# 36                                Silk Stalkings                       45
# 37                                            24                       45
# 38                                 The Mentalist                       45
# 39                                        Dallas                       44
# 40                                        Castle                       43
# 41                                    Civil Wars                       43
# 42                               Crossing Jordan                       41
# 43                                         Bones                       41
# 44                                  Falcon Crest                       40
# 45                                  Boston Legal                       39
# 46  Lois & Clark: The New Adventures of Superman                       39
# 47                                       Dragnet                       39
# 48                             The Twilight Zone                       39
# 49                                  Quantum Leap                       38
